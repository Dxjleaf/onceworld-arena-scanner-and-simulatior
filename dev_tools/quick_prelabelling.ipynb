# %% [markdown]
# # Pre-label `dataset_enemy_icons` (`img####.png` only)
# Loads the latest model checkpoint and prints top-1 prediction + probability.
# This notebook does not rename or modify files.

# %%
from pathlib import Path
import re
import cv2
import numpy as np
import torch
import torch.nn as nn
from torchvision import models

# %%
PROJECT_ROOT = Path("../")
CKPT_DIR = PROJECT_ROOT / "checkpoints"
DATASET_DIR = PROJECT_ROOT / "dataset_enemy_icons"

IMG_RE = re.compile(r"^img\d{4}\.png$", re.IGNORECASE)

ckpts = sorted(CKPT_DIR.glob("unit_resnet18_*.pt"), key=lambda p: p.stat().st_mtime, reverse=True)
if not ckpts:
    ckpts = sorted(CKPT_DIR.glob("*.pt"), key=lambda p: p.stat().st_mtime, reverse=True)
assert ckpts, f"No checkpoint found in {CKPT_DIR}"
ckpt_path = ckpts[0]
print("Using checkpoint:", ckpt_path)

img_paths = sorted([p for p in DATASET_DIR.glob("*.png") if IMG_RE.match(p.name)])
assert img_paths, f"No img####.png files found in {DATASET_DIR}"
print(f"Found {len(img_paths)} target files")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
payload = torch.load(ckpt_path, map_location=device)
class_names = payload["class_names"]
image_size = int(payload.get("image_size", 128))
mean = np.array(payload.get("normalize_mean", [0.5, 0.5, 0.5]), dtype=np.float32)
std = np.array(payload.get("normalize_std", [0.5, 0.5, 0.5]), dtype=np.float32)
std = np.where(std == 0, 1.0, std)

model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, len(class_names))
model.load_state_dict(payload["model_state_dict"], strict=True)
model = model.to(device)
model.eval()

def preprocess_icon_bgr(img):
    resized = cv2.resize(img, (image_size, image_size), interpolation=cv2.INTER_NEAREST)
    rgb = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    rgb = (rgb - mean) / std
    chw = np.transpose(rgb, (2, 0, 1))
    return torch.from_numpy(chw).unsqueeze(0).float().to(device)

for p in img_paths:
    img = cv2.imread(str(p), cv2.IMREAD_COLOR)
    if img is None:
        print(f"{p.name} | READ_FAIL | prob=0.0000")
        continue

    inp = preprocess_icon_bgr(img)
    with torch.no_grad():
        logits = model(inp)
        probs = torch.softmax(logits, dim=1)[0]

    v, i = torch.max(probs, dim=0)
    print(f"{p.name} | {class_names[int(i)]} | prob={float(v):.4f}")
# Out:
# Using checkpoint: ..\checkpoints\unit_resnet18_20260315_234905.pt
# Found 219 target files
# img0001.png | Pirate_Ship | prob=0.7940
# img0002.png | BOX | prob=0.9118
# img0003.png | The_Reaper_of_Life | prob=0.4954
# img0004.png | Bird_of_Domination | prob=0.9172
# img0005.png | Mysterious_Jar | prob=0.9298
# img0006.png | Green_Slime | prob=0.8808
# img0007.png | Skull_Wisp | prob=0.7301
# img0008.png | Mad_Shark | prob=0.5690
# img0009.png | Bird_of_Domination | prob=0.9267
# img0010.png | Pirate_Ship | prob=0.7940
# img0011.png | BOX | prob=0.9118
# img0012.png | The_Reaper_of_Life | prob=0.4954
# img0013.png | Bird_of_Domination | prob=0.9172
# img0014.png | Mysterious_Jar | prob=0.9298
# img0015.png | Green_Slime | prob=0.8808
# img0016.png | Skull_Wisp | prob=0.7301
# img0017.png | Mad_Shark | prob=0.5690
# img0018.png | Bird_of_Domination | prob=0.9267
# img0019.png | Resident_A | prob=0.8604
# img0020.png | True_Chimera | prob=0.6386
# img0021.png | Forbidden_Anubish | prob=0.8742
# img0022.png | Mysterious_Jar | prob=0.9297
# img0023.png | Rigamia | prob=0.8147
# img0024.png | The_Devoted_One | prob=0.7094
# img0025.png | ChronoZelius | prob=0.8434
# img0026.png | The_Reaper_of_Life | prob=0.6680
# img0027.png | Abyss_Lanternfish | prob=0.4459
# img0028.png | Panda | prob=0.8055
# img0029.png | Smoldering_Moeko | prob=0.9411
# img0030.png | Walking_Grave | prob=0.6785
# img0031.png | Panda | prob=0.8067
# img0032.png | Anteater_Lord | prob=0.9627
# img0033.png | Cerberus | prob=0.7365
# img0034.png | Tengu | prob=0.6693
# img0035.png | Deer_Fighter | prob=0.8100
# img0036.png | Forbidden_Anubish | prob=0.9201
# img0037.png | Aegisriel | prob=0.5261
# img0038.png | Nuu | prob=0.8490
# img0039.png | Yamata_no_Orochi | prob=0.4109
# img0040.png | Ice_Queen_Anatoyu | prob=0.9121
# img0041.png | Forbidden_Lamia | prob=0.4634
# img0042.png | Tengu | prob=0.5861
# img0043.png | Skull_Wisp | prob=0.6828
# img0044.png | Snowdarman | prob=0.8296
# img0045.png | Goblin_Mage | prob=0.8981
# img0046.png | Deer_Fighter | prob=0.7965
# img0047.png | Bird_of_Domination | prob=0.9227
# img0048.png | Ice_Crystal | prob=0.9659
# img0049.png | Aegisriel | prob=0.6720
# img0050.png | Pig_Angel | prob=0.5193
# img0051.png | Shinelion | prob=0.5227
# img0052.png | Demonblade | prob=0.7958
# img0053.png | Ancient_Fish_Zakorn | prob=0.5044
# img0054.png | Bone | prob=0.7199
# img0055.png | Crimson_Scorpion | prob=0.7083
# img0056.png | Slime_Girl_P | prob=0.8759
# img0057.png | GloomEgg | prob=0.5483
# img0058.png | Forbidden_Treant | prob=0.7980
# img0059.png | Mad_Frog | prob=0.8235
# img0060.png | Yamata_no_Orochi | prob=0.4626
# img0061.png | Skull_Wisp | prob=0.7204
# img0062.png | Abyss_Murderer | prob=0.4988
# img0063.png | Pirate_Ship | prob=0.6535
# img0064.png | Creature_Rose | prob=0.6981
# img0065.png | Ancient_Fish_Zakorn | prob=0.5330
# img0066.png | Burning_Rock | prob=0.8770
# img0067.png | Green_Slime | prob=0.8902
# img0068.png | Necro_Princess | prob=0.3814
# img0069.png | Bone_Battler | prob=0.8157
# img0070.png | True_Chimera | prob=0.6070
# img0071.png | Noctar | prob=0.1576
# img0072.png | Creature_Rose | prob=0.7653
# img0073.png | Gigant_Oak | prob=0.5819
# img0074.png | Tengu | prob=0.6674
# img0075.png | Creature_Eye | prob=0.5519
# img0076.png | Boss_Goblin | prob=0.7370
# img0077.png | Albion_Dragon | prob=0.4173
# img0078.png | Anteater_Lord | prob=0.9502
# img0079.png | Warden_of_Sin_Cycle | prob=0.5883
# img0080.png | Noctar | prob=0.1576
# img0081.png | Creature_Rose | prob=0.7653
# img0082.png | Gigant_Oak | prob=0.5819
# img0083.png | Tengu | prob=0.6674
# img0084.png | Creature_Eye | prob=0.5519
# img0085.png | Boss_Goblin | prob=0.7370
# img0086.png | Albion_Dragon | prob=0.4173
# img0087.png | Anteater_Lord | prob=0.9502
# img0088.png | Warden_of_Sin_Cycle | prob=0.5883
# img0089.png | Noctar | prob=0.1923
# img0090.png | Creature_Rose | prob=0.7668
# img0091.png | Gigant_Oak | prob=0.6405
# img0092.png | Tengu | prob=0.6936
# img0093.png | Creature_Eye | prob=0.6001
# img0094.png | Boss_Goblin | prob=0.4302
# img0095.png | Albion_Dragon | prob=0.2934
# img0096.png | Anteater_Lord | prob=0.9378
# img0097.png | Warden_of_Sin_Cycle | prob=0.6404
# img0098.png | Mysterious_Jar | prob=0.9539
# img0099.png | Lucky_Starfish | prob=0.7245
# img0100.png | The_Devoted_One | prob=0.7185
# img0101.png | Penguin_Soldier | prob=0.8807
# img0102.png | Ignisia | prob=0.7334
# img0103.png | Crimson_Scorpion | prob=0.6305
# img0104.png | Orthros | prob=0.7650
# img0105.png | Bone | prob=0.6386
# img0106.png | Flame_Bone | prob=0.9249
# img0107.png | The_Reaper_of_Life | prob=0.6491
# img0108.png | Chicken_King | prob=0.5374
# img0109.png | Flame_Ogre | prob=0.3543
# img0110.png | Smoldering_Moeko | prob=0.9511
# img0111.png | Uneune | prob=0.8492
# img0112.png | Burning_Rock | prob=0.7835
# img0113.png | Skull_Wisp | prob=0.7842
# img0114.png | Flame_Ogre | prob=0.4305
# img0115.png | Orthros | prob=0.7138
# img0116.png | Shinelion | prob=0.6120
# img0117.png | Infernal_Dragon | prob=0.8177
# img0118.png | Aegisriel | prob=0.7241
# img0119.png | Resident_B | prob=0.7582
# img0120.png | Ignisia | prob=0.7775
# img0121.png | Rainbow_Pelican_EXP | prob=0.9019
# img0122.png | Slime_Girl_P | prob=0.8270
# img0123.png | BOX | prob=0.8314
# img0124.png | Forbidden_Anubish | prob=0.9232
# img0125.png | Divine_Whale | prob=0.6711
# img0126.png | Ignisia | prob=0.7996
# img0127.png | BOX | prob=0.8109
# img0128.png | Rigamia | prob=0.6749
# img0129.png | Yamata_no_Orochi | prob=0.4817
# img0130.png | Flame_Frog | prob=0.8412
# img0131.png | Red_Goblin | prob=0.6828
# img0132.png | Necro_Princess | prob=0.5917
# img0133.png | Infernal_Dragon | prob=0.8177
# img0134.png | Skull_Wisp | prob=0.6996
# img0135.png | Gator_Crocodile | prob=0.9208
# img0136.png | Abyss_Murderer | prob=0.6427
# img0137.png | Grilled_Bird | prob=0.8953
# img0138.png | Infernal_Dragon | prob=0.7617
# img0139.png | Mad_Shark | prob=0.7463
# img0140.png | Flame_Ogre | prob=0.3724
# img0141.png | True_Chimera | prob=0.5617
# img0142.png | Walking_Grave | prob=0.6944
# img0143.png | Chicken_King | prob=0.4651
# img0144.png | Fire_Mage | prob=0.8525
# img0145.png | Pelican_EXP | prob=0.8043
# img0146.png | Crab_Club | prob=0.8918
# img0147.png | Undying_Dragon_Corpse_Izo | prob=0.7288
# img0148.png | Charred_Lizard | prob=0.3260
# img0149.png | Creature_Rose | prob=0.6885
# img0150.png | Dark_Witch | prob=0.9197
# img0151.png | Aegisriel | prob=0.7868
# img0152.png | Forbidden_Valnesia | prob=0.6664
# img0153.png | Flame_Ogre | prob=0.3535
# img0154.png | Winged_Slime | prob=0.9210
# img0155.png | Ignis_Sister | prob=0.8186
# img0156.png | Uneune | prob=0.8617
# img0157.png | Mossyham | prob=0.8787
# img0158.png | Dark_Mage | prob=0.6607
# img0159.png | Bone_Battler | prob=0.8554
# img0160.png | Necro_Princess | prob=0.5959
# img0161.png | Blaze_Mouse | prob=0.7855
# img0162.png | Winged_Slime | prob=0.9390
# img0163.png | Smoldering_Moeko | prob=0.9563
# img0164.png | ChronoZelius | prob=0.8868
# img0165.png | Resident_B | prob=0.7826
# img0166.png | Aegisriel | prob=0.5240
# img0167.png | Charred_Lizard | prob=0.3628
# img0168.png | Death_Warrior_Mummy | prob=0.8019
# img0169.png | Divine_Whale | prob=0.5835
# img0170.png | Warden | prob=0.3836
# img0171.png | Pirate_Ship | prob=0.6492
# img0172.png | Ice_Crystal | prob=0.9652
# img0173.png | Demonblade | prob=0.7898
# img0174.png | Noctar | prob=0.2466
# img0175.png | Panda | prob=0.8921
# img0176.png | Mad_Shark | prob=0.7151
# img0177.png | Anteater_Lord | prob=0.9248
# img0178.png | Bone_Battler | prob=0.8542
# img0179.png | Mad_Frog | prob=0.8035
# img0180.png | Abyss_Lanternfish | prob=0.3935
# img0181.png | Dark_Dragon | prob=0.5174
# img0182.png | Ordo_Krausus | prob=0.6744
# img0183.png | True_Chimera | prob=0.5368
# img0184.png | Rainbow_Pelican_EXP | prob=0.9215
# img0185.png | Mad_Shark | prob=0.7151
# img0186.png | Crab_Club | prob=0.9148
# img0187.png | Bone | prob=0.6387
# img0188.png | Elephant_Paladin | prob=0.7530
# img0189.png | Dark_Dragon | prob=0.5174
# img0190.png | Mad_Frog | prob=0.7655
# img0191.png | Winged_Slime | prob=0.9285
# img0192.png | Infernal_Dragon | prob=0.8109
# img0193.png | Jade_Dragon | prob=0.9017
# img0194.png | Dark_Dragon | prob=0.5614
# img0195.png | Goblin_Crew | prob=0.6860
# img0196.png | Forbidden_Bear | prob=0.9264
# img0197.png | Former_Guild_Master | prob=0.7612
# img0198.png | Albion_Dragon | prob=0.4636
# img0199.png | Forbidden_Bear | prob=0.9236
# img0200.png | Bird_of_Domination | prob=0.9167
# img0201.png | Mad_Frog | prob=0.8031
# img0202.png | Snowdarman | prob=0.8786
# img0203.png | Burning_Something | prob=0.8716
# img0204.png | Nuu | prob=0.8939
# img0205.png | Flame_Frog | prob=0.8355
# img0206.png | Chimera_Turtle | prob=0.5888
# img0207.png | Forbidden_Valnesia | prob=0.6572
# img0208.png | Radish_That_Looks_Like_a_Radish | prob=0.9569
# img0209.png | ChronoZelius | prob=0.8113
# img0210.png | Forbidden_Lamia | prob=0.6815
# img0211.png | Noctar | prob=0.3025
# img0212.png | Rigamia | prob=0.7367
# img0213.png | Warden | prob=0.3900
# img0214.png | Chimera_Turtle | prob=0.5403
# img0215.png | Resident_B | prob=0.7421
# img0216.png | Mysterious_Jar | prob=0.9470
# img0217.png | Panda | prob=0.8961
# img0218.png | Bird_of_Domination | prob=0.9053
# img0219.png | Noctar | prob=0.2264

# %%
ACCEPT_THRESHOLD = 0.40

def next_labeled_name(folder: Path, class_name: str):
    pat = re.compile(rf"^{re.escape(class_name)}_(\\d+)\\.png$", re.IGNORECASE)
    max_idx = 0
    for p in folder.iterdir():
        if not p.is_file():
            continue
        m = pat.match(p.name)
        if m:
            max_idx = max(max_idx, int(m.group(1)))

    idx = max_idx + 1
    while True:
        cand = f"{class_name}_{idx:04d}.png"
        if not (folder / cand).exists():
            return cand
        idx += 1

renamed = 0
kept = 0

img_paths = sorted([p for p in DATASET_DIR.glob("*.png") if IMG_RE.match(p.name)])
for p in img_paths:
    img = cv2.imread(str(p), cv2.IMREAD_COLOR)
    if img is None:
        print(f"KEEP {p.name} | READ_FAIL")
        kept += 1
        continue

    inp = preprocess_icon_bgr(img)
    with torch.no_grad():
        logits = model(inp)
        probs = torch.softmax(logits, dim=1)[0]

    v, i = torch.max(probs, dim=0)
    prob = float(v)
    pred_name = class_names[int(i)]

    if prob >= ACCEPT_THRESHOLD:
        new_name = next_labeled_name(DATASET_DIR, pred_name)
        new_path = DATASET_DIR / new_name
        p.rename(new_path)
        print(f"RENAME {p.name} -> {new_name} | prob={prob:.4f}")
        renamed += 1
    else:
        print(f"KEEP {p.name} | pred={pred_name} | prob={prob:.4f}")
        kept += 1

print(f"done | renamed={renamed} kept={kept}")
# Out:
# RENAME img0001.png -> Pirate_Ship_0007.png | prob=0.7940
# RENAME img0002.png -> BOX_0010.png | prob=0.9118
# RENAME img0003.png -> The_Reaper_of_Life_0009.png | prob=0.4954
# RENAME img0004.png -> Bird_of_Domination_0005.png | prob=0.9172
# RENAME img0005.png -> Mysterious_Jar_0009.png | prob=0.9298
# RENAME img0006.png -> Green_Slime_0005.png | prob=0.8808
# RENAME img0007.png -> Skull_Wisp_0007.png | prob=0.7301
# RENAME img0008.png -> Mad_Shark_0008.png | prob=0.5690
# RENAME img0009.png -> Bird_of_Domination_0006.png | prob=0.9267
# RENAME img0010.png -> Pirate_Ship_0008.png | prob=0.7940
# RENAME img0011.png -> BOX_0011.png | prob=0.9118
# RENAME img0012.png -> The_Reaper_of_Life_0010.png | prob=0.4954
# RENAME img0013.png -> Bird_of_Domination_0007.png | prob=0.9172
# RENAME img0014.png -> Mysterious_Jar_0010.png | prob=0.9298
# RENAME img0015.png -> Green_Slime_0006.png | prob=0.8808
# RENAME img0016.png -> Skull_Wisp_0008.png | prob=0.7301
# RENAME img0017.png -> Mad_Shark_0009.png | prob=0.5690
# RENAME img0018.png -> Bird_of_Domination_0008.png | prob=0.9267
# RENAME img0019.png -> Resident_A_0007.png | prob=0.8604
# RENAME img0020.png -> True_Chimera_0004.png | prob=0.6386
# RENAME img0021.png -> Forbidden_Anubish_0006.png | prob=0.8742
# RENAME img0022.png -> Mysterious_Jar_0011.png | prob=0.9297
# RENAME img0023.png -> Rigamia_0011.png | prob=0.8147
# RENAME img0024.png -> The_Devoted_One_0009.png | prob=0.7094
# RENAME img0025.png -> ChronoZelius_0005.png | prob=0.8434
# RENAME img0026.png -> The_Reaper_of_Life_0011.png | prob=0.6680
# RENAME img0027.png -> Abyss_Lanternfish_0005.png | prob=0.4459
# RENAME img0028.png -> Panda_0010.png | prob=0.8055
# RENAME img0029.png -> Smoldering_Moeko_0011.png | prob=0.9411
# RENAME img0030.png -> Walking_Grave_0011.png | prob=0.6785
# RENAME img0031.png -> Panda_0011.png | prob=0.8067
# RENAME img0032.png -> Anteater_Lord_0010.png | prob=0.9627
# RENAME img0033.png -> Cerberus_0006.png | prob=0.7365
# RENAME img0034.png -> Tengu_0011.png | prob=0.6693
# RENAME img0035.png -> Deer_Fighter_0009.png | prob=0.8100
# RENAME img0036.png -> Forbidden_Anubish_0007.png | prob=0.9201
# RENAME img0037.png -> Aegisriel_0004.png | prob=0.5261
# RENAME img0038.png -> Nuu_0006.png | prob=0.8490
# RENAME img0039.png -> Yamata_no_Orochi_0007.png | prob=0.4109
# RENAME img0040.png -> Ice_Queen_Anatoyu_0008.png | prob=0.9121
# RENAME img0041.png -> Forbidden_Lamia_0008.png | prob=0.4634
# RENAME img0042.png -> Tengu_0012.png | prob=0.5861
# RENAME img0043.png -> Skull_Wisp_0009.png | prob=0.6828
# RENAME img0044.png -> Snowdarman_0005.png | prob=0.8296
# RENAME img0045.png -> Goblin_Mage_0009.png | prob=0.8981
# RENAME img0046.png -> Deer_Fighter_0010.png | prob=0.7965
# RENAME img0047.png -> Bird_of_Domination_0009.png | prob=0.9227
# RENAME img0048.png -> Ice_Crystal_0010.png | prob=0.9659
# RENAME img0049.png -> Aegisriel_0005.png | prob=0.6720
# RENAME img0050.png -> Pig_Angel_0004.png | prob=0.5193
# RENAME img0051.png -> Shinelion_0004.png | prob=0.5227
# RENAME img0052.png -> Demonblade_0004.png | prob=0.7958
# RENAME img0053.png -> Ancient_Fish_Zakorn_0006.png | prob=0.5044
# RENAME img0054.png -> Bone_0009.png | prob=0.7199
# RENAME img0055.png -> Crimson_Scorpion_0010.png | prob=0.7083
# RENAME img0056.png -> Slime_Girl_P_0009.png | prob=0.8759
# RENAME img0057.png -> GloomEgg_0013.png | prob=0.5483
# RENAME img0058.png -> Forbidden_Treant_0002.png | prob=0.7980
# RENAME img0059.png -> Mad_Frog_0005.png | prob=0.8235
# RENAME img0060.png -> Yamata_no_Orochi_0008.png | prob=0.4626
# RENAME img0061.png -> Skull_Wisp_0010.png | prob=0.7204
# RENAME img0062.png -> Abyss_Murderer_0008.png | prob=0.4988
# RENAME img0063.png -> Pirate_Ship_0009.png | prob=0.6535
# RENAME img0064.png -> Creature_Rose_0007.png | prob=0.6981
# RENAME img0065.png -> Ancient_Fish_Zakorn_0007.png | prob=0.5330
# RENAME img0066.png -> Burning_Rock_0009.png | prob=0.8770
# RENAME img0067.png -> Green_Slime_0007.png | prob=0.8902
# KEEP img0068.png | pred=Necro_Princess | prob=0.3814
# RENAME img0069.png -> Bone_Battler_0010.png | prob=0.8157
# RENAME img0070.png -> True_Chimera_0005.png | prob=0.6070
# KEEP img0071.png | pred=Noctar | prob=0.1576
# RENAME img0072.png -> Creature_Rose_0008.png | prob=0.7653
# RENAME img0073.png -> Gigant_Oak_0006.png | prob=0.5819
# RENAME img0074.png -> Tengu_0013.png | prob=0.6674
# RENAME img0075.png -> Creature_Eye_0008.png | prob=0.5519
# RENAME img0076.png -> Boss_Goblin_0005.png | prob=0.7370
# RENAME img0077.png -> Albion_Dragon_0004.png | prob=0.4173
# RENAME img0078.png -> Anteater_Lord_0011.png | prob=0.9502
# RENAME img0079.png -> Warden_of_Sin_Cycle_0006.png | prob=0.5883
# KEEP img0080.png | pred=Noctar | prob=0.1576
# RENAME img0081.png -> Creature_Rose_0009.png | prob=0.7653
# RENAME img0082.png -> Gigant_Oak_0007.png | prob=0.5819
# RENAME img0083.png -> Tengu_0014.png | prob=0.6674
# RENAME img0084.png -> Creature_Eye_0009.png | prob=0.5519
# RENAME img0085.png -> Boss_Goblin_0006.png | prob=0.7370
# RENAME img0086.png -> Albion_Dragon_0005.png | prob=0.4173
# RENAME img0087.png -> Anteater_Lord_0012.png | prob=0.9502
# RENAME img0088.png -> Warden_of_Sin_Cycle_0007.png | prob=0.5883
# KEEP img0089.png | pred=Noctar | prob=0.1923
# RENAME img0090.png -> Creature_Rose_0010.png | prob=0.7668
# RENAME img0091.png -> Gigant_Oak_0008.png | prob=0.6405
# RENAME img0092.png -> Tengu_0015.png | prob=0.6936
# RENAME img0093.png -> Creature_Eye_0010.png | prob=0.6001
# RENAME img0094.png -> Boss_Goblin_0007.png | prob=0.4302
# KEEP img0095.png | pred=Albion_Dragon | prob=0.2934
# RENAME img0096.png -> Anteater_Lord_0013.png | prob=0.9378
# RENAME img0097.png -> Warden_of_Sin_Cycle_0008.png | prob=0.6404
# RENAME img0098.png -> Mysterious_Jar_0012.png | prob=0.9539
# RENAME img0099.png -> Lucky_Starfish_0005.png | prob=0.7245
# RENAME img0100.png -> The_Devoted_One_0010.png | prob=0.7185
# RENAME img0101.png -> Penguin_Soldier_0012.png | prob=0.8807
# RENAME img0102.png -> Ignisia_0010.png | prob=0.7334
# RENAME img0103.png -> Crimson_Scorpion_0011.png | prob=0.6305
# RENAME img0104.png -> Orthros_0010.png | prob=0.7650
# RENAME img0105.png -> Bone_0010.png | prob=0.6386
# RENAME img0106.png -> Flame_Bone_0009.png | prob=0.9249
# RENAME img0107.png -> The_Reaper_of_Life_0012.png | prob=0.6491
# RENAME img0108.png -> Chicken_King_0007.png | prob=0.5374
# KEEP img0109.png | pred=Flame_Ogre | prob=0.3543
# RENAME img0110.png -> Smoldering_Moeko_0012.png | prob=0.9511
# RENAME img0111.png -> Uneune_0011.png | prob=0.8492
# RENAME img0112.png -> Burning_Rock_0010.png | prob=0.7835
# RENAME img0113.png -> Skull_Wisp_0011.png | prob=0.7842
# RENAME img0114.png -> Flame_Ogre_0011.png | prob=0.4305
# RENAME img0115.png -> Orthros_0011.png | prob=0.7138
# RENAME img0116.png -> Shinelion_0005.png | prob=0.6120
# RENAME img0117.png -> Infernal_Dragon_0007.png | prob=0.8177
# RENAME img0118.png -> Aegisriel_0006.png | prob=0.7241
# RENAME img0119.png -> Resident_B_0007.png | prob=0.7582
# RENAME img0120.png -> Ignisia_0011.png | prob=0.7775
# RENAME img0121.png -> Rainbow_Pelican_EXP_0011.png | prob=0.9019
# RENAME img0122.png -> Slime_Girl_P_0010.png | prob=0.8270
# RENAME img0123.png -> BOX_0012.png | prob=0.8314
# RENAME img0124.png -> Forbidden_Anubish_0008.png | prob=0.9232
# RENAME img0125.png -> Divine_Whale_0012.png | prob=0.6711
# RENAME img0126.png -> Ignisia_0012.png | prob=0.7996
# RENAME img0127.png -> BOX_0013.png | prob=0.8109
# RENAME img0128.png -> Rigamia_0012.png | prob=0.6749
# RENAME img0129.png -> Yamata_no_Orochi_0009.png | prob=0.4817
# RENAME img0130.png -> Flame_Frog_0009.png | prob=0.8412
# RENAME img0131.png -> Red_Goblin_0008.png | prob=0.6828
# RENAME img0132.png -> Necro_Princess_0008.png | prob=0.5917
# RENAME img0133.png -> Infernal_Dragon_0008.png | prob=0.8177
# RENAME img0134.png -> Skull_Wisp_0012.png | prob=0.6996
# RENAME img0135.png -> Gator_Crocodile_0012.png | prob=0.9208
# RENAME img0136.png -> Abyss_Murderer_0009.png | prob=0.6427
# RENAME img0137.png -> Grilled_Bird_0010.png | prob=0.8953
# RENAME img0138.png -> Infernal_Dragon_0009.png | prob=0.7617
# RENAME img0139.png -> Mad_Shark_0010.png | prob=0.7463
# KEEP img0140.png | pred=Flame_Ogre | prob=0.3724
# RENAME img0141.png -> True_Chimera_0006.png | prob=0.5617
# RENAME img0142.png -> Walking_Grave_0012.png | prob=0.6944
# RENAME img0143.png -> Chicken_King_0008.png | prob=0.4651
# RENAME img0144.png -> Fire_Mage_0005.png | prob=0.8525
# RENAME img0145.png -> Pelican_EXP_0010.png | prob=0.8043
# RENAME img0146.png -> Crab_Club_0008.png | prob=0.8918
# RENAME img0147.png -> Undying_Dragon_Corpse_Izo_0008.png | prob=0.7288
# KEEP img0148.png | pred=Charred_Lizard | prob=0.3260
# RENAME img0149.png -> Creature_Rose_0011.png | prob=0.6885
# RENAME img0150.png -> Dark_Witch_0007.png | prob=0.9197
# RENAME img0151.png -> Aegisriel_0007.png | prob=0.7868
# RENAME img0152.png -> Forbidden_Valnesia_0009.png | prob=0.6664
# KEEP img0153.png | pred=Flame_Ogre | prob=0.3535
# RENAME img0154.png -> Winged_Slime_0008.png | prob=0.9210
# RENAME img0155.png -> Ignis_Sister_0008.png | prob=0.8186
# RENAME img0156.png -> Uneune_0012.png | prob=0.8617
# RENAME img0157.png -> Mossyham_0004.png | prob=0.8787
# RENAME img0158.png -> Dark_Mage_0007.png | prob=0.6607
# RENAME img0159.png -> Bone_Battler_0011.png | prob=0.8554
# RENAME img0160.png -> Necro_Princess_0009.png | prob=0.5959
# RENAME img0161.png -> Blaze_Mouse_0010.png | prob=0.7855
# RENAME img0162.png -> Winged_Slime_0009.png | prob=0.9390
# RENAME img0163.png -> Smoldering_Moeko_0013.png | prob=0.9563
# RENAME img0164.png -> ChronoZelius_0006.png | prob=0.8868
# RENAME img0165.png -> Resident_B_0008.png | prob=0.7826
# RENAME img0166.png -> Aegisriel_0008.png | prob=0.5240
# KEEP img0167.png | pred=Charred_Lizard | prob=0.3628
# RENAME img0168.png -> Death_Warrior_Mummy_0004.png | prob=0.8019
# RENAME img0169.png -> Divine_Whale_0013.png | prob=0.5835
# KEEP img0170.png | pred=Warden | prob=0.3836
# RENAME img0171.png -> Pirate_Ship_0010.png | prob=0.6492
# RENAME img0172.png -> Ice_Crystal_0011.png | prob=0.9652
# RENAME img0173.png -> Demonblade_0005.png | prob=0.7898
# KEEP img0174.png | pred=Noctar | prob=0.2466
# RENAME img0175.png -> Panda_0012.png | prob=0.8921
# RENAME img0176.png -> Mad_Shark_0011.png | prob=0.7151
# RENAME img0177.png -> Anteater_Lord_0014.png | prob=0.9248
# RENAME img0178.png -> Bone_Battler_0012.png | prob=0.8542
# RENAME img0179.png -> Mad_Frog_0006.png | prob=0.8035
# KEEP img0180.png | pred=Abyss_Lanternfish | prob=0.3935
# RENAME img0181.png -> Dark_Dragon_0011.png | prob=0.5174
# RENAME img0182.png -> Ordo_Krausus_0010.png | prob=0.6744
# RENAME img0183.png -> True_Chimera_0007.png | prob=0.5368
# RENAME img0184.png -> Rainbow_Pelican_EXP_0012.png | prob=0.9215
# RENAME img0185.png -> Mad_Shark_0012.png | prob=0.7151
# RENAME img0186.png -> Crab_Club_0009.png | prob=0.9148
# RENAME img0187.png -> Bone_0011.png | prob=0.6387
# RENAME img0188.png -> Elephant_Paladin_0007.png | prob=0.7530
# RENAME img0189.png -> Dark_Dragon_0012.png | prob=0.5174
# RENAME img0190.png -> Mad_Frog_0007.png | prob=0.7655
# RENAME img0191.png -> Winged_Slime_0010.png | prob=0.9285
# RENAME img0192.png -> Infernal_Dragon_0010.png | prob=0.8109
# RENAME img0193.png -> Jade_Dragon_0006.png | prob=0.9017
# RENAME img0194.png -> Dark_Dragon_0013.png | prob=0.5614
# RENAME img0195.png -> Goblin_Crew_0010.png | prob=0.6860
# RENAME img0196.png -> Forbidden_Bear_0010.png | prob=0.9264
# RENAME img0197.png -> Former_Guild_Master_0007.png | prob=0.7612
# RENAME img0198.png -> Albion_Dragon_0006.png | prob=0.4636
# RENAME img0199.png -> Forbidden_Bear_0011.png | prob=0.9236
# RENAME img0200.png -> Bird_of_Domination_0010.png | prob=0.9167
# RENAME img0201.png -> Mad_Frog_0008.png | prob=0.8031
# RENAME img0202.png -> Snowdarman_0006.png | prob=0.8786
# RENAME img0203.png -> Burning_Something_0003.png | prob=0.8716
# RENAME img0204.png -> Nuu_0007.png | prob=0.8939
# RENAME img0205.png -> Flame_Frog_0010.png | prob=0.8355
# RENAME img0206.png -> Chimera_Turtle_0008.png | prob=0.5888
# RENAME img0207.png -> Forbidden_Valnesia_0010.png | prob=0.6572
# RENAME img0208.png -> Radish_That_Looks_Like_a_Radish_0008.png | prob=0.9569
# RENAME img0209.png -> ChronoZelius_0007.png | prob=0.8113
# RENAME img0210.png -> Forbidden_Lamia_0009.png | prob=0.6815
# KEEP img0211.png | pred=Noctar | prob=0.3025
# RENAME img0212.png -> Rigamia_0013.png | prob=0.7367
# KEEP img0213.png | pred=Warden | prob=0.3900
# RENAME img0214.png -> Chimera_Turtle_0009.png | prob=0.5403
# RENAME img0215.png -> Resident_B_0009.png | prob=0.7421
# RENAME img0216.png -> Mysterious_Jar_0013.png | prob=0.9470
# RENAME img0217.png -> Panda_0013.png | prob=0.8961
# RENAME img0218.png -> Bird_of_Domination_0011.png | prob=0.9053
# KEEP img0219.png | pred=Noctar | prob=0.2264
# done | renamed=203 kept=16
