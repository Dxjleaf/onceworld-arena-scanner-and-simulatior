# %% [markdown]
# # Pre-label `dataset_enemy_icons` (`img####.png` only)
# Loads the latest model checkpoint and prints top-1 prediction + probability.
# This notebook does not rename or modify files.

# %%
from pathlib import Path
import re
import cv2
import numpy as np
import torch
import torch.nn as nn
from torchvision import models

# %%
PROJECT_ROOT = Path("../")
CKPT_DIR = PROJECT_ROOT / "checkpoints"
DATASET_DIR = PROJECT_ROOT / "dataset_enemy_icons"

IMG_RE = re.compile(r"^img\d{4}\.png$", re.IGNORECASE)

ckpts = sorted(CKPT_DIR.glob("unit_resnet18_*.pt"), key=lambda p: p.stat().st_mtime, reverse=True)
if not ckpts:
    ckpts = sorted(CKPT_DIR.glob("*.pt"), key=lambda p: p.stat().st_mtime, reverse=True)
assert ckpts, f"No checkpoint found in {CKPT_DIR}"
ckpt_path = ckpts[0]
print("Using checkpoint:", ckpt_path)

img_paths = sorted([p for p in DATASET_DIR.glob("*.png") if IMG_RE.match(p.name)])
assert img_paths, f"No img####.png files found in {DATASET_DIR}"
print(f"Found {len(img_paths)} target files")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
payload = torch.load(ckpt_path, map_location=device)
class_names = payload["class_names"]
image_size = int(payload.get("image_size", 128))
mean = np.array(payload.get("normalize_mean", [0.5, 0.5, 0.5]), dtype=np.float32)
std = np.array(payload.get("normalize_std", [0.5, 0.5, 0.5]), dtype=np.float32)
std = np.where(std == 0, 1.0, std)

model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, len(class_names))
model.load_state_dict(payload["model_state_dict"], strict=True)
model = model.to(device)
model.eval()

def preprocess_icon_bgr(img):
    resized = cv2.resize(img, (image_size, image_size), interpolation=cv2.INTER_NEAREST)
    rgb = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    rgb = (rgb - mean) / std
    chw = np.transpose(rgb, (2, 0, 1))
    return torch.from_numpy(chw).unsqueeze(0).float().to(device)

for p in img_paths:
    img = cv2.imread(str(p), cv2.IMREAD_COLOR)
    if img is None:
        print(f"{p.name} | READ_FAIL | prob=0.0000")
        continue

    inp = preprocess_icon_bgr(img)
    with torch.no_grad():
        logits = model(inp)
        probs = torch.softmax(logits, dim=1)[0]

    v, i = torch.max(probs, dim=0)
    print(f"{p.name} | {class_names[int(i)]} | prob={float(v):.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 PROJECT_ROOT = Path(__file__).resolve().parent.parent
#       2 CKPT_DIR = PROJECT_ROOT / "checkpoints"
#       3 DATASET_DIR = PROJECT_ROOT / "dataset_enemy_icons"
#
# NameError: name '__file__' is not defined

# %%
ACCEPT_THRESHOLD = 0.40

def next_labeled_name(folder: Path, class_name: str):
    pat = re.compile(rf"^{re.escape(class_name)}_(\\d+)\\.png$", re.IGNORECASE)
    max_idx = 0
    for p in folder.iterdir():
        if not p.is_file():
            continue
        m = pat.match(p.name)
        if m:
            max_idx = max(max_idx, int(m.group(1)))

    idx = max_idx + 1
    while True:
        cand = f"{class_name}_{idx:04d}.png"
        if not (folder / cand).exists():
            return cand
        idx += 1

renamed = 0
kept = 0

img_paths = sorted([p for p in DATASET_DIR.glob("*.png") if IMG_RE.match(p.name)])
for p in img_paths:
    img = cv2.imread(str(p), cv2.IMREAD_COLOR)
    if img is None:
        print(f"KEEP {p.name} | READ_FAIL")
        kept += 1
        continue

    inp = preprocess_icon_bgr(img)
    with torch.no_grad():
        logits = model(inp)
        probs = torch.softmax(logits, dim=1)[0]

    v, i = torch.max(probs, dim=0)
    prob = float(v)
    pred_name = class_names[int(i)]

    if prob >= ACCEPT_THRESHOLD:
        new_name = next_labeled_name(DATASET_DIR, pred_name)
        new_path = DATASET_DIR / new_name
        p.rename(new_path)
        print(f"RENAME {p.name} -> {new_name} | prob={prob:.4f}")
        renamed += 1
    else:
        print(f"KEEP {p.name} | pred={pred_name} | prob={prob:.4f}")
        kept += 1

print(f"done | renamed={renamed} kept={kept}")
# Out:
# RENAME img0001.png -> Chimera_Turtle_0006.png | prob=0.4273
# KEEP img0002.png | pred=The_Reaper_of_Life | prob=0.0794
# RENAME img0003.png -> True_Chimera_0003.png | prob=0.4179
# RENAME img0004.png -> Ignis_Sister_0006.png | prob=0.8914
# KEEP img0005.png | pred=Dark_Mage | prob=0.2760
# RENAME img0006.png -> Anteater_Lord_0009.png | prob=0.8521
# RENAME img0007.png -> Burning_Something_0002.png | prob=0.8241
# RENAME img0008.png -> Ignis_Sister_0007.png | prob=0.8763
# RENAME img0009.png -> Uneune_0010.png | prob=0.6040
# RENAME img0010.png -> Skull_Wisp_0006.png | prob=0.6181
# RENAME img0011.png -> Deer_Fighter_0005.png | prob=0.6622
# RENAME img0012.png -> Dawn_God_Tomodachi_0004.png | prob=0.8022
# RENAME img0013.png -> Rigamia_0010.png | prob=0.8419
# RENAME img0014.png -> Death_Warrior_Mummy_0002.png | prob=0.6171
# RENAME img0015.png -> Forbidden_Lamia_0007.png | prob=0.4844
# RENAME img0016.png -> Former_Guild_Master_0006.png | prob=0.6848
# RENAME img0017.png -> Dawn_God_Tomodachi_0005.png | prob=0.8405
# RENAME img0018.png -> Ignisia_0007.png | prob=0.9071
# RENAME img0019.png -> Snow_Mokera_0008.png | prob=0.6940
# RENAME img0020.png -> Slime_Girl_P_0005.png | prob=0.8762
# RENAME img0021.png -> Dark_Dragon_0008.png | prob=0.5547
# KEEP img0022.png | pred=Gigant_Oak | prob=0.2641
# RENAME img0023.png -> Tengu_0009.png | prob=0.7142
# RENAME img0024.png -> Anubis_0006.png | prob=0.8766
# RENAME img0025.png -> Dark_Witch_0006.png | prob=0.8122
# RENAME img0026.png -> Forbidden_Valnesia_0008.png | prob=0.6803
# RENAME img0027.png -> Lamp_Spirit_0005.png | prob=0.6836
# RENAME img0028.png -> Floating_Squid_0007.png | prob=0.8042
# RENAME img0029.png -> Mad_Frog_0004.png | prob=0.7503
# RENAME img0030.png -> Ordo_Krausus_0009.png | prob=0.8325
# RENAME img0031.png -> Ice_Crystal_0009.png | prob=0.9605
# RENAME img0032.png -> Penguin_Soldier_0008.png | prob=0.8668
# RENAME img0033.png -> Slime_Girl_P_0006.png | prob=0.8746
# RENAME img0034.png -> Walking_Grave_0009.png | prob=0.5286
# RENAME img0035.png -> Grilled_Bird_0007.png | prob=0.8780
# RENAME img0036.png -> Tengu_0010.png | prob=0.7666
# RENAME img0037.png -> BOX_0008.png | prob=0.9005
# RENAME img0038.png -> Boss_Goblin_0003.png | prob=0.4051
# RENAME img0039.png -> Gator_Crocodile_0010.png | prob=0.9293
# RENAME img0040.png -> Bone_0007.png | prob=0.7460
# RENAME img0041.png -> Dawn_God_Tomodachi_0006.png | prob=0.7582
# RENAME img0042.png -> Deer_Fighter_0006.png | prob=0.7077
# RENAME img0043.png -> Chicken_King_0006.png | prob=0.8424
# RENAME img0044.png -> Winged_Slime_0007.png | prob=0.9130
# RENAME img0045.png -> GloomEgg_0012.png | prob=0.7426
# RENAME img0046.png -> Iron_Trap_Bloom_0006.png | prob=0.7593
# KEEP img0047.png | pred=Dark_Mage | prob=0.3723
# RENAME img0048.png -> The_Reaper_of_Life_0008.png | prob=0.7849
# RENAME img0049.png -> The_Devoted_One_0008.png | prob=0.8726
# RENAME img0050.png -> Bone_Battler_0007.png | prob=0.7600
# RENAME img0051.png -> Penguin_Soldier_0009.png | prob=0.8293
# RENAME img0052.png -> Anubis_0007.png | prob=0.7705
# RENAME img0053.png -> Ice_Queen_Anatoyu_0006.png | prob=0.9263
# RENAME img0054.png -> Slime_Girl_P_0007.png | prob=0.8702
# RENAME img0055.png -> Grilled_Bird_0008.png | prob=0.8468
# RENAME img0056.png -> Flame_Frog_0008.png | prob=0.7417
# RENAME img0057.png -> Burning_Rock_0008.png | prob=0.7880
# RENAME img0058.png -> Orthros_0009.png | prob=0.8801
# RENAME img0059.png -> Snow_Mokera_0009.png | prob=0.8017
# RENAME img0060.png -> Red_Goblin_0007.png | prob=0.6920
# RENAME img0061.png -> Desert_Doggo_0005.png | prob=0.6309
# RENAME img0062.png -> Blaze_Mouse_0008.png | prob=0.7891
# RENAME img0063.png -> Dark_Dragon_0009.png | prob=0.4982
# RENAME img0064.png -> Ignisia_0008.png | prob=0.9071
# KEEP img0065.png | pred=Cerberus | prob=0.1848
# RENAME img0066.png -> Flame_Ogre_0010.png | prob=0.4166
# RENAME img0067.png -> Ignisia_0009.png | prob=0.8954
# RENAME img0068.png -> Bone_Battler_0008.png | prob=0.6985
# RENAME img0069.png -> Goblin_Crew_0009.png | prob=0.6628
# RENAME img0070.png -> Radish_That_Looks_Like_a_Radish_0007.png | prob=0.7366
# RENAME img0071.png -> Deer_Fighter_0007.png | prob=0.6596
# RENAME img0072.png -> Mysterious_Jar_0008.png | prob=0.8568
# RENAME img0073.png -> Necro_Princess_0006.png | prob=0.6057
# RENAME img0074.png -> Resident_B_0005.png | prob=0.7529
# RENAME img0075.png -> Ancient_Fish_Zakorn_0005.png | prob=0.5448
# RENAME img0076.png -> Abyss_Murderer_0007.png | prob=0.5638
# RENAME img0077.png -> Lucky_Starfish_0004.png | prob=0.7583
# RENAME img0078.png -> Walking_Grave_0010.png | prob=0.4673
# RENAME img0079.png -> Death_Warrior_Mummy_0003.png | prob=0.5972
# RENAME img0080.png -> Forbidden_Bear_0009.png | prob=0.9535
# RENAME img0081.png -> Deer_Fighter_0008.png | prob=0.6726
# RENAME img0082.png -> Ice_Queen_Anatoyu_0007.png | prob=0.8855
# RENAME img0083.png -> The_One_of_Zero_0008.png | prob=0.8509
# RENAME img0084.png -> BOX_0009.png | prob=0.9004
# RENAME img0085.png -> Bone_Battler_0009.png | prob=0.6056
# RENAME img0086.png -> Nightmare_Statue_0008.png | prob=0.7254
# RENAME img0087.png -> Bone_0008.png | prob=0.4997
# RENAME img0088.png -> Chimera_Turtle_0007.png | prob=0.4273
# RENAME img0089.png -> Necro_Princess_0007.png | prob=0.5905
# RENAME img0090.png -> Dark_Dragon_0010.png | prob=0.4560
# RENAME img0091.png -> Grilled_Bird_0009.png | prob=0.8780
# RENAME img0092.png -> Penguin_Soldier_0010.png | prob=0.8602
# RENAME img0093.png -> Mad_Shark_0007.png | prob=0.6467
# RENAME img0094.png -> Nightmare_Statue_0009.png | prob=0.6849
# RENAME img0095.png -> Blaze_Mouse_0009.png | prob=0.7891
# RENAME img0096.png -> Nuu_0005.png | prob=0.8769
# RENAME img0097.png -> Cerberus_0005.png | prob=0.8535
# RENAME img0098.png -> Green_Slime_0004.png | prob=0.8863
# RENAME img0099.png -> Resident_B_0006.png | prob=0.7578
# RENAME img0100.png -> Anubis_0008.png | prob=0.8925
# RENAME img0101.png -> Slime_Girl_P_0008.png | prob=0.8762
# RENAME img0102.png -> Aegisriel_0003.png | prob=0.8552
# RENAME img0103.png -> Penguin_Soldier_0011.png | prob=0.8247
# KEEP img0104.png | pred=Boss_Goblin | prob=0.3451
# RENAME img0105.png -> Gator_Crocodile_0011.png | prob=0.9371
# RENAME img0106.png -> Panda_0009.png | prob=0.7940
# RENAME img0107.png -> Egypt_Ashura_0005.png | prob=0.4710
# done | renamed=101 kept=6
